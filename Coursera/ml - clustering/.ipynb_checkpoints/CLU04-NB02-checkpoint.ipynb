# %% [markdown]
# ## Fitting a diagonal covariance Gaussian mixture model to text data
#
# In a previous assignment, we explored k-means clustering for a high-dimensional Wikipedia dataset. We can also model this data with a mixture of Gaussians, though with increasing dimension we run into two important issues associated with using a full covariance matrix for each component.
#  * Computational cost becomes prohibitive in high dimensions: score calculations have complexity cubic in the number of dimensions M if the Gaussian has a full covariance matrix.
#  * A model with many parameters require more data: observe that a full covariance matrix for an M-dimensional Gaussian will have M(M+1)/2 parameters to fit. With the number of parameters growing roughly as the square of the dimension, it may quickly become impossible to find a sufficient amount of data to make good inferences.
#
# Both of these issues are avoided if we require the covariance matrix of each component to be diagonal, as then it has only M parameters to fit and the score computation decomposes into M univariate score calculations. Recall from the lecture that the M-step for the full covariance is:
#
# \begin{align*}
# \hat{\Sigma}_k &= \frac{1}{N_k^{soft}} \sum_{i=1}^N r_{ik} (x_i-\hat{\mu}_k)(x_i - \hat{\mu}_k)^T
# \end{align*}
#
# Note that this is a square matrix with M rows and M columns, and the above equation implies that the (v, w) element is computed by
#
# \begin{align*}
# \hat{\Sigma}_{k, v, w} &= \frac{1}{N_k^{soft}} \sum_{i=1}^N r_{ik} (x_{iv}-\hat{\mu}_{kv})(x_{iw} - \hat{\mu}_{kw})
# \end{align*}
#
# When we assume that this is a diagonal matrix, then non-diagonal elements are assumed to be zero and we only need to compute each of the M elements along the diagonal independently using the following equation.
#
# \begin{align*}
# \hat{\sigma}^2_{k, v} &= \hat{\Sigma}_{k, v, v}  \\
# &= \frac{1}{N_k^{soft}} \sum_{i=1}^N r_{ik} (x_{iv}-\hat{\mu}_{kv})^2
# \end{align*}
#
# In this section, we will use an EM implementation to fit a Gaussian mixture model with **diagonal** covariances to a subset of the Wikipedia dataset. The implementation uses the above equation to compute each variance term.
#
# We'll begin by importing the dataset and coming up with a useful representation for each article. After running our algorithm on the data, we will explore the output to see whether we can give a meaningful interpretation to the fitted parameters in our model.

# %% [markdown]
# **Note to Amazon EC2 users**: To conserve memory, make sure to stop all the other notebooks before running this notebook.

# %% [markdown]
# ## Import necessary packages

# %%
from __future__ import print_function # to conform python 2.x print to python 3.x
import turicreate

# %% [markdown]
# We also have a Python file containing implementations for several functions that will be used during the course of this assignment.

# %%
from em_utilities import *

# %% [markdown]
# ## Load Wikipedia data and extract TF-IDF features

# %% [markdown]
# Load Wikipedia data and transform each of the first 5000 document into a TF-IDF representation.

# %%
wiki = turicreate.SFrame('data/people_wiki.sframe/').head(5000)
wiki['tf_idf'] = turicreate.text_analytics.tf_idf(wiki['text'])

# %% [markdown]
# Using a utility we provide, we will create a sparse matrix representation of the documents. This is the same utility function you used during the previous assignment on k-means with text data.

# %%
wiki = wiki.add_row_number()
tf_idf, map_word_to_index = sframe_to_scipy(wiki, 'tf_idf')
map_index_to_word = dict([[map_word_to_index[i], i] for i in map_word_to_index.keys()])
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-5-eb94bb74e179> in <module>
# ----> 1 wiki = wiki.add_row_number()
#       2 tf_idf, map_word_to_index = sframe_to_scipy(wiki, 'tf_idf')
#       3 map_index_to_word = dict([[map_word_to_index[i], i] for i in map_word_to_index.keys()])
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/turicreate/data_structures/sframe.py in add_row_number(self, column_name, start, inplace)
#    5875
#    5876         if column_name in self.column_names():
# -> 5877             raise RuntimeError("Column '" + column_name + "' already exists in the current SFrame")
#    5878
#    5879         the_col = _create_sequential_sarray(self.num_rows(), start)
#
# RuntimeError: Column 'id' already exists in the current SFrame

# %% [markdown]
# As in the previous assignment, we will normalize each document's TF-IDF vector to be a unit vector.

# %%
# %%time
tf_idf = normalize(tf_idf)
# Out:
# CPU times: user 9.7 ms, sys: 5.85 ms, total: 15.6 ms
# Wall time: 14.7 ms

# %% [markdown]
# We can check that the length (Euclidean norm) of each row is now 1.0, as expected.

# %%
for i in range(5):
    doc = tf_idf[i]
    print(np.linalg.norm(doc.todense()))
# Out:
# 1.0
# 1.0
# 0.9999999999999997
# 1.0000000000000004
# 1.0

# %%
wiki.head()
# Out:
# Columns:
# 	id	int
# 	URI	str
# 	name	str
# 	text	str
# 	tf_idf	dict
#
# Rows: 10
#
# Data:
# +----+-------------------------------+---------------------+
# | id |              URI              |         name        |
# +----+-------------------------------+---------------------+
# | 0  | <http://dbpedia.org/resour... |    Digby Morrell    |
# | 1  | <http://dbpedia.org/resour... |    Alfred J. Lewy   |
# | 2  | <http://dbpedia.org/resour... |    Harpdog Brown    |
# | 3  | <http://dbpedia.org/resour... | Franz Rottensteiner |
# | 4  | <http://dbpedia.org/resour... |        G-Enka       |
# | 5  | <http://dbpedia.org/resour... |    Sam Henderson    |
# | 6  | <http://dbpedia.org/resour... |    Aaron LaCrate    |
# | 7  | <http://dbpedia.org/resour... |   Trevor Ferguson   |
# | 8  | <http://dbpedia.org/resour... |     Grant Nelson    |
# | 9  | <http://dbpedia.org/resour... |     Cathy Caruth    |
# +----+-------------------------------+---------------------+
# +-------------------------------+-------------------------------+
# |              text             |             tf_idf            |
# +-------------------------------+-------------------------------+
# | digby morrell born 10 octo... | {'melbourne': 3.8167128256... |
# | alfred j lewy aka sandy le... | {'time': 1.345536368647722... |
# | harpdog brown is a singer ... | {'time': 1.345536368647722... |
# | franz rottensteiner born i... | {'kurdlawitzpreis': 8.5171... |
# | henry krvits born 30 decem... | {'curtis': 5.1498973614297... |
# | sam henderson born october... | {'journal': 3.092243173934... |
# | aaron lacrate is an americ... | {'including': 1.2364959960... |
# | trevor ferguson aka john f... | {'concordia': 6.3199686140... |
# | grant nelson born 27 april... | {'knuckles': 8.51719319141... |
# | cathy caruth born 1955 is ... | {'n3': 8.517193191416238, ... |
# +-------------------------------+-------------------------------+
# [10 rows x 5 columns]

# %% [markdown]
# ## EM in high dimensions
#
# EM for high-dimensional data requires some special treatment:
#  * E step and M step must be vectorized as much as possible, as explicit loops are dreadfully slow in Python.
#  * All operations must be cast in terms of sparse matrix operations, to take advantage of computational savings enabled by sparsity of data.
#  * Initially, some words may be entirely absent from a cluster, causing the M step to produce zero mean and variance for those words.  This means any data point with one of those words will have 0 probability of being assigned to that cluster since the cluster allows for no variability (0 variance) around that count being 0 (0 mean). Since there is a small chance for those words to later appear in the cluster, we instead assign a small positive variance (~1e-10). Doing so also prevents numerical overflow.
#
# We provide the complete implementation for you in the file `em_utilities.py`. For those who are interested, you can read through the code to see how the sparse matrix implementation differs from the previous assignment.
#
# You are expected to answer some quiz questions using the results of clustering.

# %% [markdown]
# **Initializing mean parameters using k-means**
#
# Recall from the lectures that EM for Gaussian mixtures is very sensitive to the choice of initial means. With a bad initial set of means, EM may produce clusters that span a large area and are mostly overlapping. To eliminate such bad outcomes, we first produce a suitable set of initial means by using the cluster centers from running k-means.  That is, we first run k-means and then take the final set of means from the converged solution as the initial means in our EM algorithm.

# %%
# %%time 

from sklearn.cluster import KMeans

np.random.seed(5)
num_clusters = 25

# Use scikit-learn's k-means to simplify workflow
#kmeans_model = KMeans(n_clusters=num_clusters, n_init=5, max_iter=400, random_state=1, n_jobs=-1) # uncomment to use parallelism -- may break on your installation
kmeans_model = KMeans(n_clusters=num_clusters, n_init=5, max_iter=400, random_state=1, n_jobs=1)
kmeans_model.fit(tf_idf)
centroids, cluster_assignment = kmeans_model.cluster_centers_, kmeans_model.labels_

means = [centroid for centroid in centroids]
# Out:
# CPU times: user 2min 30s, sys: 19.2 s, total: 2min 50s
# Wall time: 1min 44s

# %%
np.bincount(cluster_assignment)[24]
# Out:
# 358

# %% [markdown]
# **Initializing cluster weights**
#
# We will initialize each cluster weight to be the proportion of documents assigned to that cluster by k-means above.

# %%
# %%time 

num_docs = tf_idf.shape[0]
weights = []
for i in range(num_clusters):
    # Compute the number of data points assigned to cluster i:
    num_assigned = np.bincount(cluster_assignment)[i] # YOUR CODE HERE
    w = float(num_assigned) / num_docs
    weights.append(w)
# Out:
# CPU times: user 959 µs, sys: 967 µs, total: 1.93 ms
# Wall time: 1.03 ms

# %% [markdown]
# **Initializing covariances**
#
# To initialize our covariance parameters, we compute $\hat{\sigma}_{k, j}^2 = \sum_{i=1}^{N}(x_{i,j} - \hat{\mu}_{k, j})^2$ for each feature $j$.  For features with really tiny variances, we assign 1e-8 instead to prevent numerical instability. We do this computation in a vectorized fashion in the following code block.

# %%
covs = []
for i in range(num_clusters):
    member_rows = tf_idf[cluster_assignment==i]
    cov = (member_rows.multiply(member_rows) - 2*member_rows.dot(diag(means[i]))).sum(axis=0).A1 / member_rows.shape[0] \
          + means[i]**2
    cov[cov < 1e-8] = 1e-8
    covs.append(cov)

# %% [markdown]
# **Running EM**
#
# Now that we have initialized all of our parameters, run EM.

# %%
out = EM_for_high_dimension(tf_idf, means, covs, weights, cov_smoothing=1e-10)

# %%
out['loglik']
# Out:
# [3879297479.366981, 4883345753.533131, 4883345753.533131]

# %% [markdown]
# ## Interpret clustering results

# %% [markdown]
# In contrast to k-means, EM is able to explicitly model clusters of varying sizes and proportions. The relative magnitude of variances in the word dimensions tell us much about the nature of the clusters.
#
# Write yourself a cluster visualizer as follows.  Examining each cluster's mean vector, list the 5 words with the largest mean values (5 most common words in the cluster). For each word, also include the associated variance parameter (diagonal element of the covariance matrix).
#
# A sample output may be:
# ```
# ==========================================================
# Cluster 0: Largest mean parameters in cluster
#
# Word        Mean        Variance
# football    1.08e-01    8.64e-03
# season      5.80e-02    2.93e-03
# club        4.48e-02    1.99e-03
# league      3.94e-02    1.08e-03
# played      3.83e-02    8.45e-04
# ...
# ```

# %%
# Fill in the blanks
def visualize_EM_clusters(tf_idf, means, covs, map_index_to_word):
    print('')
    print('==========================================================')
    
    num_clusters = len(means)
    for c in range(num_clusters):
        print('Cluster {0:d}: Largest mean parameters in cluster '.format(c))
        print('\n{0: <12}{1: <12}{2: <12}'.format('Word', 'Mean', 'Variance'))
        
        # The k'th element of sorted_word_ids should be the index of the word 
        # that has the k'th-largest value in the cluster mean. Hint: Use np.argsort().
        sorted_word_ids = np.argsort(out['means'][c], axis=0)  # YOUR CODE HERE

        for i in sorted_word_ids[:5]:
            print('{0: <12}{1:<10.2e}{2:10.2e}'.format(map_index_to_word[i], 
                                                       means[c][i],
                                                       covs[c][i]))
        print('\n==========================================================')

# %%
'''By EM'''
visualize_EM_clusters(tf_idf, out['means'], out['covs'], map_index_to_word)
# Out:
# ==========================================================
# Cluster 0: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 0           0.00e+00    1.00e-10
# onceinalifetime0.00e+00    1.00e-10
# oncehe      0.00e+00    1.00e-10
# oncegreat   0.00e+00    1.00e-10
# onceerasmus 0.00e+00    1.00e-10
#
# ==========================================================
# Cluster 1: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 0           0.00e+00    1.00e-10
# nehring     0.00e+00    1.00e-10
# nehemia     0.00e+00    1.00e-10
# nehe        0.00e+00    1.00e-10
# negros      0.00e+00    1.00e-10
#
# ==========================================================
# Cluster 2: Largest mean parameters in cluster
#
# Word        Mean        Variance
# karaganda   0.00e+00    1.00e-10
# oaau        0.00e+00    1.00e-10
# o2in        0.00e+00    1.00e-10
# o2          0.00e+00    1.00e-10
# nzs         0.00e+00    1.00e-10
#
# ==========================================================
# Cluster 3: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 0           0.00e+00    1.00e-10
# ocha        0.00e+00    1.00e-10
# och         0.00e+00    1.00e-10
# oceansstrange0.00e+00    1.00e-10
# oceanside   0.00e+00    1.00e-10
#
# ==========================================================
# Cluster 4: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 0           0.00e+00    1.00e-10
# novruzlu    0.00e+00    1.00e-10
# novosti     0.00e+00    1.00e-10
# novosibirsk 0.00e+00    1.00e-10
# novorossiysk0.00e+00    1.00e-10
#
# ==========================================================
# Cluster 5: Largest mean parameters in cluster
#
# Word        Mean        Variance
# karaganda   0.00e+00    1.00e-10
# onda        0.00e+00    1.00e-10
# oncology    0.00e+00    1.00e-10
# oncologist  0.00e+00    1.00e-10
# oncogenomics0.00e+00    1.00e-10
#
# ==========================================================
# Cluster 6: Largest mean parameters in cluster
#
# Word        Mean        Variance
# karaganda   0.00e+00    1.00e-10
# nyunt       0.00e+00    1.00e-10
# nyumon      0.00e+00    1.00e-10
# nyu         0.00e+00    1.00e-10
# nytn        0.00e+00    1.00e-10
#
# ==========================================================
# Cluster 7: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 0           0.00e+00    1.00e-10
# obergfll    0.00e+00    1.00e-10
# oberfell    0.00e+00    1.00e-10
# oberdada    0.00e+00    1.00e-10
# oberassistent0.00e+00    1.00e-10
#
# ==========================================================
# Cluster 8: Largest mean parameters in cluster
#
# Word        Mean        Variance
# karaganda   0.00e+00    1.00e-10
# oncat       0.00e+00    1.00e-10
# oncamera    0.00e+00    1.00e-10
# onbusinessie0.00e+00    1.00e-10
# onboard     0.00e+00    1.00e-10
#
# ==========================================================
# Cluster 9: Largest mean parameters in cluster
#
# Word        Mean        Variance
# karaganda   0.00e+00    1.00e-10
# nimbleness  0.00e+00    1.00e-10
# nimble      0.00e+00    1.00e-10
# nimbin      0.00e+00    1.00e-10
# nimal       0.00e+00    1.00e-10
#
# ==========================================================
# Cluster 10: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 0           0.00e+00    1.00e-10
# nudity      0.00e+00    1.00e-10
# nudists     0.00e+00    1.00e-10
# nudist      0.00e+00    1.00e-10
# nudism      0.00e+00    1.00e-10
#
# ==========================================================
# Cluster 11: Largest mean parameters in cluster
#
# Word        Mean        Variance
# karaganda   0.00e+00    1.00e-10
# newscast    0.00e+00    1.00e-10
# newsbytesph 0.00e+00    1.00e-10
# newsbytescom0.00e+00    1.00e-10
# newsbytes   0.00e+00    1.00e-10
#
# ==========================================================
# Cluster 12: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 0           0.00e+00    1.00e-10
# occhi       0.00e+00    1.00e-10
# occean      0.00e+00    1.00e-10
# occasionswhite0.00e+00    1.00e-10
# occasionswheelers0.00e+00    1.00e-10
#
# ==========================================================
# Cluster 13: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 0           0.00e+00    1.00e-10
# ola         0.00e+00    1.00e-10
# ol          0.00e+00    1.00e-10
# okwy        0.00e+00    1.00e-10
# okwesilieze 0.00e+00    1.00e-10
#
# ==========================================================
# Cluster 14: Largest mean parameters in cluster
#
# Word        Mean        Variance
# karaganda   0.00e+00    1.00e-10
# officialpruitts0.00e+00    1.00e-10
# officialpruitt0.00e+00    1.00e-10
# officially  0.00e+00    1.00e-10
# officialafter0.00e+00    1.00e-10
#
# ==========================================================
# Cluster 15: Largest mean parameters in cluster
#
# Word        Mean        Variance
# karaganda   0.00e+00    1.00e-10
# olari       0.00e+00    1.00e-10
# olakanye    0.00e+00    1.00e-10
# olaine      0.00e+00    1.00e-10
# olafur      0.00e+00    1.00e-10
#
# ==========================================================
# Cluster 16: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 0           0.00e+00    1.00e-10
# omara       0.00e+00    1.00e-10
# omar        0.00e+00    1.00e-10
# omanon      0.00e+00    1.00e-10
# omani       0.00e+00    1.00e-10
#
# ==========================================================
# Cluster 17: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 0           0.00e+00    1.00e-10
# motife      0.00e+00    1.00e-10
# motif       0.00e+00    1.00e-10
# motian      0.00e+00    1.00e-10
# moti        0.00e+00    1.00e-10
#
# ==========================================================
# Cluster 18: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 0           0.00e+00    1.00e-10
# nujazzacid  0.00e+00    1.00e-10
# nuit        0.00e+00    1.00e-10
# nuim        0.00e+00    1.00e-10
# nuijamiehet 0.00e+00    1.00e-10
#
# ==========================================================
# Cluster 19: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 0           0.00e+00    1.00e-10
# omission    0.00e+00    1.00e-10
# omicron     0.00e+00    1.00e-10
# omha        0.00e+00    1.00e-10
# omfl        0.00e+00    1.00e-10
#
# ==========================================================
# Cluster 20: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 0           0.00e+00    1.00e-10
# oehlen      0.00e+00    1.00e-10
# oedipus     0.00e+00    1.00e-10
# oechslinvaudenay0.00e+00    1.00e-10
# oecds       0.00e+00    1.00e-10
#
# ==========================================================
# Cluster 21: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 0           0.00e+00    1.00e-10
# nsdc        0.00e+00    1.00e-10
# nscad       0.00e+00    1.00e-10
# nscaa       0.00e+00    1.00e-10
# nsblod      0.00e+00    1.00e-10
#
# ==========================================================
# Cluster 22: Largest mean parameters in cluster
#
# Word        Mean        Variance
# karaganda   0.00e+00    1.00e-10
# notching    0.00e+00    1.00e-10
# notched     0.00e+00    1.00e-10
# notation    0.00e+00    1.00e-10
# notary      0.00e+00    1.00e-10
#
# ==========================================================
# Cluster 23: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 0           0.00e+00    1.00e-10
# obamas      0.00e+00    1.00e-10
# obamain     0.00e+00    1.00e-10
# obamagivhan 0.00e+00    1.00e-10
# obama       0.00e+00    1.00e-10
#
# ==========================================================
# Cluster 24: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 0           0.00e+00    1.00e-10
# newspeak    0.00e+00    1.00e-10
# newspapertrudgill0.00e+00    1.00e-10
# newspapersmagazines0.00e+00    1.00e-10
# newspapersin0.00e+00    1.00e-10
#
# ==========================================================

# %% [markdown]
# **Quiz Question**. Select all the topics that have a cluster in the model created above. [multiple choice]
#
# - Baseball
# - Basketball
# - Soccer/Football
# - Music
# - Politics
# - Law
# - Finance

# %% [markdown]
# ## Comparing to random initialization

# %% [markdown]
# Create variables for randomly initializing the EM algorithm. Complete the following code block.

# %%
np.random.seed(5) # See the note below to see why we set seed=5.
num_clusters = len(means)
num_docs, num_words = tf_idf.shape

random_means = []
random_covs = []
random_weights = []

for k in range(num_clusters):
    
    # Create a numpy array of length num_words with random normally distributed values.
    # Use the standard univariate normal distribution (mean 0, variance 1).
    # YOUR CODE HERE
    mean = np.random.normal(0, 1, num_words)
    
    # Create a numpy array of length num_words with random values uniformly distributed between 1 and 5.
    # YOUR CODE HERE
    cov = np.random.uniform(1.0, 5.0, num_words)

    # Initially give each cluster equal weight.
    # YOUR CODE HERE
    weight = 1./num_clusters
    
    random_means.append(mean)
    random_covs.append(cov)
    random_weights.append(weight)

# %% [markdown]
# **Quiz Question**: Try fitting EM with the random initial parameters you created above. (Use `cov_smoothing=1e-5`.) Store the result to `out_random_init`. What is the final loglikelihood that the algorithm converges to?

# %%
out_random_init = EM_for_high_dimension(tf_idf, means, covs, weights, cov_smoothing=1e-5)

# %% [markdown]
# **Quiz Question:** Is the final loglikelihood larger or smaller than the final loglikelihood we obtained above when initializing EM with the results from running k-means?

# %%
out_random_init['loglik']
# Out:
# [3879297479.366981, 2364860294.3649483]

# %%
4883345753.533131 < 2364860294.3649483
# Out:
# False

# %% [markdown]
# **Quiz Question**: For the above model, `out_random_init`, use the `visualize_EM_clusters` method you created above. Are the clusters more or less interpretable than the ones found after initializing using k-means?

# %%
visualize_EM_clusters(tf_idf, out['means'], out['covs'], map_index_to_word)
# Out:
# ==========================================================
# Cluster 0: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 0           0.00e+00    1.00e-10
# onceinalifetime0.00e+00    1.00e-10
# oncehe      0.00e+00    1.00e-10
# oncegreat   0.00e+00    1.00e-10
# onceerasmus 0.00e+00    1.00e-10
#
# ==========================================================
# Cluster 1: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 0           0.00e+00    1.00e-10
# nehring     0.00e+00    1.00e-10
# nehemia     0.00e+00    1.00e-10
# nehe        0.00e+00    1.00e-10
# negros      0.00e+00    1.00e-10
#
# ==========================================================
# Cluster 2: Largest mean parameters in cluster
#
# Word        Mean        Variance
# karaganda   0.00e+00    1.00e-10
# oaau        0.00e+00    1.00e-10
# o2in        0.00e+00    1.00e-10
# o2          0.00e+00    1.00e-10
# nzs         0.00e+00    1.00e-10
#
# ==========================================================
# Cluster 3: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 0           0.00e+00    1.00e-10
# ocha        0.00e+00    1.00e-10
# och         0.00e+00    1.00e-10
# oceansstrange0.00e+00    1.00e-10
# oceanside   0.00e+00    1.00e-10
#
# ==========================================================
# Cluster 4: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 0           0.00e+00    1.00e-10
# novruzlu    0.00e+00    1.00e-10
# novosti     0.00e+00    1.00e-10
# novosibirsk 0.00e+00    1.00e-10
# novorossiysk0.00e+00    1.00e-10
#
# ==========================================================
# Cluster 5: Largest mean parameters in cluster
#
# Word        Mean        Variance
# karaganda   0.00e+00    1.00e-10
# onda        0.00e+00    1.00e-10
# oncology    0.00e+00    1.00e-10
# oncologist  0.00e+00    1.00e-10
# oncogenomics0.00e+00    1.00e-10
#
# ==========================================================
# Cluster 6: Largest mean parameters in cluster
#
# Word        Mean        Variance
# karaganda   0.00e+00    1.00e-10
# nyunt       0.00e+00    1.00e-10
# nyumon      0.00e+00    1.00e-10
# nyu         0.00e+00    1.00e-10
# nytn        0.00e+00    1.00e-10
#
# ==========================================================
# Cluster 7: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 0           0.00e+00    1.00e-10
# obergfll    0.00e+00    1.00e-10
# oberfell    0.00e+00    1.00e-10
# oberdada    0.00e+00    1.00e-10
# oberassistent0.00e+00    1.00e-10
#
# ==========================================================
# Cluster 8: Largest mean parameters in cluster
#
# Word        Mean        Variance
# karaganda   0.00e+00    1.00e-10
# oncat       0.00e+00    1.00e-10
# oncamera    0.00e+00    1.00e-10
# onbusinessie0.00e+00    1.00e-10
# onboard     0.00e+00    1.00e-10
#
# ==========================================================
# Cluster 9: Largest mean parameters in cluster
#
# Word        Mean        Variance
# karaganda   0.00e+00    1.00e-10
# nimbleness  0.00e+00    1.00e-10
# nimble      0.00e+00    1.00e-10
# nimbin      0.00e+00    1.00e-10
# nimal       0.00e+00    1.00e-10
#
# ==========================================================
# Cluster 10: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 0           0.00e+00    1.00e-10
# nudity      0.00e+00    1.00e-10
# nudists     0.00e+00    1.00e-10
# nudist      0.00e+00    1.00e-10
# nudism      0.00e+00    1.00e-10
#
# ==========================================================
# Cluster 11: Largest mean parameters in cluster
#
# Word        Mean        Variance
# karaganda   0.00e+00    1.00e-10
# newscast    0.00e+00    1.00e-10
# newsbytesph 0.00e+00    1.00e-10
# newsbytescom0.00e+00    1.00e-10
# newsbytes   0.00e+00    1.00e-10
#
# ==========================================================
# Cluster 12: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 0           0.00e+00    1.00e-10
# occhi       0.00e+00    1.00e-10
# occean      0.00e+00    1.00e-10
# occasionswhite0.00e+00    1.00e-10
# occasionswheelers0.00e+00    1.00e-10
#
# ==========================================================
# Cluster 13: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 0           0.00e+00    1.00e-10
# ola         0.00e+00    1.00e-10
# ol          0.00e+00    1.00e-10
# okwy        0.00e+00    1.00e-10
# okwesilieze 0.00e+00    1.00e-10
#
# ==========================================================
# Cluster 14: Largest mean parameters in cluster
#
# Word        Mean        Variance
# karaganda   0.00e+00    1.00e-10
# officialpruitts0.00e+00    1.00e-10
# officialpruitt0.00e+00    1.00e-10
# officially  0.00e+00    1.00e-10
# officialafter0.00e+00    1.00e-10
#
# ==========================================================
# Cluster 15: Largest mean parameters in cluster
#
# Word        Mean        Variance
# karaganda   0.00e+00    1.00e-10
# olari       0.00e+00    1.00e-10
# olakanye    0.00e+00    1.00e-10
# olaine      0.00e+00    1.00e-10
# olafur      0.00e+00    1.00e-10
#
# ==========================================================
# Cluster 16: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 0           0.00e+00    1.00e-10
# omara       0.00e+00    1.00e-10
# omar        0.00e+00    1.00e-10
# omanon      0.00e+00    1.00e-10
# omani       0.00e+00    1.00e-10
#
# ==========================================================
# Cluster 17: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 0           0.00e+00    1.00e-10
# motife      0.00e+00    1.00e-10
# motif       0.00e+00    1.00e-10
# motian      0.00e+00    1.00e-10
# moti        0.00e+00    1.00e-10
#
# ==========================================================
# Cluster 18: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 0           0.00e+00    1.00e-10
# nujazzacid  0.00e+00    1.00e-10
# nuit        0.00e+00    1.00e-10
# nuim        0.00e+00    1.00e-10
# nuijamiehet 0.00e+00    1.00e-10
#
# ==========================================================
# Cluster 19: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 0           0.00e+00    1.00e-10
# omission    0.00e+00    1.00e-10
# omicron     0.00e+00    1.00e-10
# omha        0.00e+00    1.00e-10
# omfl        0.00e+00    1.00e-10
#
# ==========================================================
# Cluster 20: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 0           0.00e+00    1.00e-10
# oehlen      0.00e+00    1.00e-10
# oedipus     0.00e+00    1.00e-10
# oechslinvaudenay0.00e+00    1.00e-10
# oecds       0.00e+00    1.00e-10
#
# ==========================================================
# Cluster 21: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 0           0.00e+00    1.00e-10
# nsdc        0.00e+00    1.00e-10
# nscad       0.00e+00    1.00e-10
# nscaa       0.00e+00    1.00e-10
# nsblod      0.00e+00    1.00e-10
#
# ==========================================================
# Cluster 22: Largest mean parameters in cluster
#
# Word        Mean        Variance
# karaganda   0.00e+00    1.00e-10
# notching    0.00e+00    1.00e-10
# notched     0.00e+00    1.00e-10
# notation    0.00e+00    1.00e-10
# notary      0.00e+00    1.00e-10
#
# ==========================================================
# Cluster 23: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 0           0.00e+00    1.00e-10
# obamas      0.00e+00    1.00e-10
# obamain     0.00e+00    1.00e-10
# obamagivhan 0.00e+00    1.00e-10
# obama       0.00e+00    1.00e-10
#
# ==========================================================
# Cluster 24: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 0           0.00e+00    1.00e-10
# newspeak    0.00e+00    1.00e-10
# newspapertrudgill0.00e+00    1.00e-10
# newspapersmagazines0.00e+00    1.00e-10
# newspapersin0.00e+00    1.00e-10
#
# ==========================================================

# %%
# YOUR CODE HERE. Use visualize_EM_clusters, which will require you to pass in tf_idf and map_index_to_word.
visualize_EM_clusters(tf_idf, out_random_init['means'], out_random_init['covs'], map_index_to_word)
# Out:
# ==========================================================
# Cluster 0: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 0           0.00e+00    1.00e-05
# onceinalifetime0.00e+00    1.00e-05
# oncehe      0.00e+00    1.00e-05
# oncegreat   0.00e+00    1.00e-05
# onceerasmus 0.00e+00    1.00e-05
#
# ==========================================================
# Cluster 1: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 0           0.00e+00    1.00e-05
# nehring     0.00e+00    1.00e-05
# nehemia     0.00e+00    1.00e-05
# nehe        0.00e+00    1.00e-05
# negros      0.00e+00    1.00e-05
#
# ==========================================================
# Cluster 2: Largest mean parameters in cluster
#
# Word        Mean        Variance
# karaganda   0.00e+00    1.00e-05
# oaau        0.00e+00    1.00e-05
# o2in        0.00e+00    1.00e-05
# o2          0.00e+00    1.00e-05
# nzs         0.00e+00    1.00e-05
#
# ==========================================================
# Cluster 3: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 0           0.00e+00    1.00e-05
# ocha        0.00e+00    1.00e-05
# och         0.00e+00    1.00e-05
# oceansstrange0.00e+00    1.00e-05
# oceanside   0.00e+00    1.00e-05
#
# ==========================================================
# Cluster 4: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 0           0.00e+00    1.00e-05
# novruzlu    0.00e+00    1.00e-05
# novosti     0.00e+00    1.00e-05
# novosibirsk 0.00e+00    1.00e-05
# novorossiysk0.00e+00    1.00e-05
#
# ==========================================================
# Cluster 5: Largest mean parameters in cluster
#
# Word        Mean        Variance
# karaganda   0.00e+00    1.00e-05
# onda        0.00e+00    1.00e-05
# oncology    0.00e+00    1.00e-05
# oncologist  0.00e+00    1.00e-05
# oncogenomics0.00e+00    1.00e-05
#
# ==========================================================
# Cluster 6: Largest mean parameters in cluster
#
# Word        Mean        Variance
# karaganda   0.00e+00    1.00e-05
# nyunt       0.00e+00    1.00e-05
# nyumon      0.00e+00    1.00e-05
# nyu         0.00e+00    1.00e-05
# nytn        0.00e+00    1.00e-05
#
# ==========================================================
# Cluster 7: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 0           0.00e+00    1.00e-05
# obergfll    0.00e+00    1.00e-05
# oberfell    0.00e+00    1.00e-05
# oberdada    0.00e+00    1.00e-05
# oberassistent0.00e+00    1.00e-05
#
# ==========================================================
# Cluster 8: Largest mean parameters in cluster
#
# Word        Mean        Variance
# karaganda   0.00e+00    1.00e-05
# oncat       0.00e+00    1.00e-05
# oncamera    0.00e+00    1.00e-05
# onbusinessie0.00e+00    1.00e-05
# onboard     0.00e+00    1.00e-05
#
# ==========================================================
# Cluster 9: Largest mean parameters in cluster
#
# Word        Mean        Variance
# karaganda   0.00e+00    1.00e-05
# nimbleness  0.00e+00    1.00e-05
# nimble      0.00e+00    1.00e-05
# nimbin      0.00e+00    1.00e-05
# nimal       0.00e+00    1.00e-05
#
# ==========================================================
# Cluster 10: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 0           0.00e+00    1.00e-05
# nudity      0.00e+00    1.00e-05
# nudists     0.00e+00    1.00e-05
# nudist      0.00e+00    1.00e-05
# nudism      0.00e+00    1.00e-05
#
# ==========================================================
# Cluster 11: Largest mean parameters in cluster
#
# Word        Mean        Variance
# karaganda   0.00e+00    1.00e-05
# newscast    0.00e+00    1.00e-05
# newsbytesph 0.00e+00    1.00e-05
# newsbytescom0.00e+00    1.00e-05
# newsbytes   0.00e+00    1.00e-05
#
# ==========================================================
# Cluster 12: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 0           0.00e+00    1.00e-05
# occhi       0.00e+00    1.00e-05
# occean      0.00e+00    1.00e-05
# occasionswhite0.00e+00    1.00e-05
# occasionswheelers0.00e+00    1.00e-05
#
# ==========================================================
# Cluster 13: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 0           0.00e+00    1.00e-05
# ola         0.00e+00    1.00e-05
# ol          0.00e+00    1.00e-05
# okwy        0.00e+00    1.00e-05
# okwesilieze 0.00e+00    1.00e-05
#
# ==========================================================
# Cluster 14: Largest mean parameters in cluster
#
# Word        Mean        Variance
# karaganda   0.00e+00    1.00e-05
# officialpruitts0.00e+00    1.00e-05
# officialpruitt0.00e+00    1.00e-05
# officially  0.00e+00    1.00e-05
# officialafter0.00e+00    1.00e-05
#
# ==========================================================
# Cluster 15: Largest mean parameters in cluster
#
# Word        Mean        Variance
# karaganda   0.00e+00    1.00e-05
# olari       0.00e+00    1.00e-05
# olakanye    0.00e+00    1.00e-05
# olaine      0.00e+00    1.00e-05
# olafur      0.00e+00    1.00e-05
#
# ==========================================================
# Cluster 16: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 0           0.00e+00    1.00e-05
# omara       0.00e+00    1.00e-05
# omar        0.00e+00    1.00e-05
# omanon      0.00e+00    1.00e-05
# omani       0.00e+00    1.00e-05
#
# ==========================================================
# Cluster 17: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 0           0.00e+00    1.00e-05
# motife      0.00e+00    1.00e-05
# motif       0.00e+00    1.00e-05
# motian      0.00e+00    1.00e-05
# moti        0.00e+00    1.00e-05
#
# ==========================================================
# Cluster 18: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 0           0.00e+00    1.00e-05
# nujazzacid  0.00e+00    1.00e-05
# nuit        0.00e+00    1.00e-05
# nuim        0.00e+00    1.00e-05
# nuijamiehet 0.00e+00    1.00e-05
#
# ==========================================================
# Cluster 19: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 0           0.00e+00    1.00e-05
# omission    0.00e+00    1.00e-05
# omicron     0.00e+00    1.00e-05
# omha        0.00e+00    1.00e-05
# omfl        0.00e+00    1.00e-05
#
# ==========================================================
# Cluster 20: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 0           0.00e+00    1.00e-05
# oehlen      0.00e+00    1.00e-05
# oedipus     0.00e+00    1.00e-05
# oechslinvaudenay0.00e+00    1.00e-05
# oecds       0.00e+00    1.00e-05
#
# ==========================================================
# Cluster 21: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 0           0.00e+00    1.00e-05
# nsdc        0.00e+00    1.00e-05
# nscad       0.00e+00    1.00e-05
# nscaa       0.00e+00    1.00e-05
# nsblod      0.00e+00    1.00e-05
#
# ==========================================================
# Cluster 22: Largest mean parameters in cluster
#
# Word        Mean        Variance
# karaganda   0.00e+00    1.00e-05
# notching    0.00e+00    1.00e-05
# notched     0.00e+00    1.00e-05
# notation    0.00e+00    1.00e-05
# notary      0.00e+00    1.00e-05
#
# ==========================================================
# Cluster 23: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 0           0.00e+00    1.00e-05
# obamas      0.00e+00    1.00e-05
# obamain     0.00e+00    1.00e-05
# obamagivhan 0.00e+00    1.00e-05
# obama       0.00e+00    1.00e-05
#
# ==========================================================
# Cluster 24: Largest mean parameters in cluster
#
# Word        Mean        Variance
# 0           0.00e+00    1.00e-05
# newspeak    0.00e+00    1.00e-05
# newspapertrudgill0.00e+00    1.00e-05
# newspapersmagazines0.00e+00    1.00e-05
# newspapersin0.00e+00    1.00e-05
#
# ==========================================================

# %% [markdown]
# **Note**: Random initialization may sometimes produce a superior fit than k-means initialization. We do not claim that random initialization is always worse. However, this section does illustrate that random initialization often produces much worse clustering than k-means counterpart. This is the reason why we provide the particular random seed (`np.random.seed(5)`).

# %% [markdown]
# ## Takeaway
#
# In this assignment we were able to apply the EM algorithm to a mixture of Gaussians model of text data. This was made possible by modifying the model to assume a diagonal covariance for each cluster, and by modifying the implementation to use a sparse matrix representation. In the second part you explored the role of k-means initialization on the convergence of the model as well as the interpretability of the clusters.
