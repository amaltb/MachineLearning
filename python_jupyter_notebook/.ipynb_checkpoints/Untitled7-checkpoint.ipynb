# %%
import json

# %%
with open('/Users/ambabu/Downloads/data.json', 'r') as f:
    res = json.load(f)

res
# Out:
# {'keys': {'metricName': 'attach',
#   'mgmtUnitName': 'Exp United States',
#   'metricTopic': 'css_insurance_kpi',
#   'value_name': '1day-count',
#   'queue': 'greyhound',
#   'lob': 'SA HOTEL'},
#  'values': [[9.008356094360352, 1567407600000],
#   [8.8658447265625, 1567494000000],
#   [8.530137062072754, 1567580400000],
#   [8.312365531921387, 1567666800000],
#   [8.605040550231934, 1567753200000],
#   [8.009273529052734, 1567839600000],
#   [7.569420337677002, 1567926000000],
#   [8.055587768554688, 1568012400000],
#   [8.02108097076416, 1568098800000],
#   [7.863863945007324, 1568185200000],
#   [8.207578659057617, 1568271600000],
#   [8.651389122009277, 1568358000000],
#   [8.600829124450684, 1568444400000],
#   [7.895956993103027, 1568530800000],
#   [7.765273094177246, 1568617200000],
#   [7.607799053192139, 1568703600000],
#   [8.134580612182617, 1568790000000],
#   [8.523761749267578, 1568876400000],
#   [9.005765914916992, 1568962800000],
# ...

# %%
val = res.get('values')
val
# Out:
# [[9.008356094360352, 1567407600000],
#  [8.8658447265625, 1567494000000],
#  [8.530137062072754, 1567580400000],
#  [8.312365531921387, 1567666800000],
#  [8.605040550231934, 1567753200000],
#  [8.009273529052734, 1567839600000],
#  [7.569420337677002, 1567926000000],
#  [8.055587768554688, 1568012400000],
#  [8.02108097076416, 1568098800000],
#  [7.863863945007324, 1568185200000],
#  [8.207578659057617, 1568271600000],
#  [8.651389122009277, 1568358000000],
#  [8.600829124450684, 1568444400000],
#  [7.895956993103027, 1568530800000],
#  [7.765273094177246, 1568617200000],
#  [7.607799053192139, 1568703600000],
#  [8.134580612182617, 1568790000000],
#  [8.523761749267578, 1568876400000],
#  [9.005765914916992, 1568962800000],
#  [8.795527458190918, 1569049200000],
#  [8.539621353149414, 1569135600000],
#  [8.102376937866211, 1569222000000],
#  [8.122414588928223, 1569308400000],
#  [8.54345417022705, 1569394800000],
#  [8.136341094970703, 1569481200000],
# ...

# %%
val_1 = [x[0] for x in val]

# %%
val_1
# Out:
# [9.008356094360352,
#  8.8658447265625,
#  8.530137062072754,
#  8.312365531921387,
#  8.605040550231934,
#  8.009273529052734,
#  7.569420337677002,
#  8.055587768554688,
#  8.02108097076416,
#  7.863863945007324,
#  8.207578659057617,
#  8.651389122009277,
#  8.600829124450684,
#  7.895956993103027,
#  7.765273094177246,
#  7.607799053192139,
#  8.134580612182617,
#  8.523761749267578,
#  9.005765914916992,
#  8.795527458190918,
#  8.539621353149414,
#  8.102376937866211,
#  8.122414588928223,
#  8.54345417022705,
#  8.136341094970703,
#  8.856781959533691,
#  9.01478099822998,
#  6.9231462478637695]

# %%
import numpy as np

# %%
np.mean(val_1) - 2.2 * np.std(val_1)
# Out:
# 7.209840008783958

# %%
mean = np.mean(val_1)
stdDev = np.std(val_1)
mean, stdDev
#mean / (stdDev + 0.0001)
# Out:
# (8.295298201697213, 0.493390087687843)

# %%
2.2 - 19.207946969053218 + 2.2
# Out:
# -14.80794696905322
