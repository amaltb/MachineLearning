# %%
import pandas as pd

# %%
df = pd.read_excel('/Users/ambabu/Documents/PersonalDocuments/code-samples/python_jupyter_notebook/data/EXPE.xlsm', 
                   sheet_name='EXPE', parse_dates=['Date'], index_col='Date')
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-08-10  132.160004  133.119995  130.899994  131.889999  130.535156
# 2018-08-13  132.500000  132.789993  131.139999  131.490005  130.139267
# 2018-08-14  132.000000  134.229996  131.550003  133.490005  132.118744
# 2018-08-15  132.550003  133.229996  130.330002  131.699997  130.347122
# 2018-08-16  133.279999  133.309998  130.949997  131.199997  129.852264
# ...                ...         ...         ...         ...         ...
# 2019-08-05  126.900002  128.279999  125.470001  126.500000  126.500000
# 2019-08-06  127.320000  128.139999  125.919998  127.059998  127.059998
# 2019-08-07  125.540001  127.449997  124.699997  127.169998  127.169998
# 2019-08-08  128.350006  131.339996  127.309998  130.470001  130.470001
# 2019-08-09  129.919998  130.699997  128.009995  128.919998  128.919998
#
#              Volume
# Date
# 2018-08-10  1078300
# 2018-08-13   808500
# 2018-08-14  1403700
# ...

# %%
# %matplotlib inline
df.Close.resample('M').mean().plot()

# %%
df['2019-07-01':'2019-07-07']
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-07-01  133.949997  134.199997  132.119995  133.240005  133.240005
# 2019-07-02  133.229996  134.050003  132.320007  134.009995  134.009995
# 2019-07-03  134.089996  135.000000  133.059998  134.880005  134.880005
# 2019-07-05  134.160004  135.169998  132.919998  135.119995  135.119995
#
#              Volume
# Date
# 2019-07-01  1280900
# 2019-07-02  1047500
# 2019-07-03   733600
# 2019-07-05   736400

# %%
from pandas.tseries.holiday import

# %%
dates = ['2017-01-01 12:30:00 PM', 'Jan 1,2019 00:30:00', '01/01/2019', '01.01.2019', '2019/01/01']

dt = pd.to_datetime(dates)
dt
# Out:
# DatetimeIndex(['2017-01-01 12:30:00', '2019-01-01 00:30:00',
#                '2019-01-01 00:00:00', '2019-01-01 00:00:00',
#                '2019-01-01 00:00:00'],
#               dtype='datetime64[ns]', freq=None)

# %%
dt = pd.date_range('2019-01-01', '2019-01-31', freq='b')
dt
# Out:
# DatetimeIndex(['2019-01-01', '2019-01-02', '2019-01-03', '2019-01-04',
#                '2019-01-07', '2019-01-08', '2019-01-09', '2019-01-10',
#                '2019-01-11', '2019-01-14', '2019-01-15', '2019-01-16',
#                '2019-01-17', '2019-01-18', '2019-01-21', '2019-01-22',
#                '2019-01-23', '2019-01-24', '2019-01-25', '2019-01-28',
#                '2019-01-29', '2019-01-30', '2019-01-31'],
#               dtype='datetime64[ns]', freq='B')

# %%
from pandas.tseries.holiday import AbstractHolidayCalendar, Holiday, nearest_workday
from pandas.tseries.offsets import CustomBusinessDay

class MyHolidayCalendar(AbstractHolidayCalendar):
    rules = [
        Holiday('Amal"s birthday', month=6, day=12, observance=nearest_workday)
    ]
myc = CustomBusinessDay(calendar=MyHolidayCalendar())
myc

dt1 = pd.date_range('2019-06-01', '2019-06-30', freq='b')
dt1
# Out:
# DatetimeIndex(['2019-06-03', '2019-06-04', '2019-06-05', '2019-06-06',
#                '2019-06-07', '2019-06-10', '2019-06-11', '2019-06-12',
#                '2019-06-13', '2019-06-14', '2019-06-17', '2019-06-18',
#                '2019-06-19', '2019-06-20', '2019-06-21', '2019-06-24',
#                '2019-06-25', '2019-06-26', '2019-06-27', '2019-06-28'],
#               dtype='datetime64[ns]', freq='B')
